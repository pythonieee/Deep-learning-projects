# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    event_id  num_perimeters_0_5h  dt_first_last_0_5h  \
# 0  10892457                    3            4.265188
# 1  11757157                    2            1.169918
# 2  11945086                    4            4.777526
# 3  12044083                    1            0.000000
# 4  12052347                    2            4.975273
#
#    low_temporal_resolution_0_5h  area_first_ha  area_growth_abs_0_5h  \
# 0                             0      79.696304              2.875935
# 1                             0       8.946749              0.000000
# 2                             0     106.482638              0.000000
# 3                             1      67.631125              0.000000
# 4                             0      35.632874              0.000000
#
#    area_growth_rel_0_5h  area_growth_rate_ha_per_h  log1p_area_first  \
# 0              0.036086                   0.674281          4.390693
# 1              0.000000                   0.000000          2.297246
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 37 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   event_id                      221 non-null    int64
#  1   num_perimeters_0_5h           221 non-null    int64
#  2   dt_first_last_0_5h            221 non-null    float64
#  3   low_temporal_resolution_0_5h  221 non-null    int64
#  4   area_first_ha                 221 non-null    float64
#  5   area_growth_abs_0_5h          221 non-null    float64
#  6   area_growth_rel_0_5h          221 non-null    float64
#  7   area_growth_rate_ha_per_h     221 non-null    float64
#  8   log1p_area_first              221 non-null    float64
#  9   log1p_growth                  221 non-null    float64
#  10  log_area_ratio_0_5h           221 non-null    float64
#  11  relative_growth_0_5h          221 non-null    float64
# ...

# %%
meta_data = pd.read_csv("metaData.csv")

# %%
meta_Data = pd.read_csv("metaData.csv")

# %%
meta_Data[["column" ,"description"]]
# Out:
#                           column  \
# 0                       event_id
# 1              time_to_hit_hours
# 2                          event
# 3            num_perimeters_0_5h
# 4             dt_first_last_0_5h
# 5   low_temporal_resolution_0_5h
# 6                  area_first_ha
# 7           area_growth_abs_0_5h
# 8           area_growth_rel_0_5h
# 9      area_growth_rate_ha_per_h
# 10              log1p_area_first
# 11                  log1p_growth
# 12           log_area_ratio_0_5h
# 13          relative_growth_0_5h
# 14               radial_growth_m
# 15    radial_growth_rate_m_per_h
# 16       centroid_displacement_m
# 17        centroid_speed_m_per_h
# 18            spread_bearing_deg
# 19            spread_bearing_sin
# 20            spread_bearing_cos
# 21              dist_min_ci_0_5h
# 22              dist_std_ci_0_5h
# 23           dist_change_ci_0_5h
# 24            dist_slope_ci_0_5h
# 25         closing_speed_m_per_h
# 26     closing_speed_abs_m_per_h
# ...
